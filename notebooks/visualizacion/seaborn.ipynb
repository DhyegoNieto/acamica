# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv('./../../dataset/fifa/data.csv')
dataframe.head(2)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus
#
#        ...       Composure Marking StandingTackle  SlidingTackle GKDiving  \
# 0      ...            96.0    33.0           28.0           26.0      6.0
# 1      ...            95.0    28.0           31.0           23.0      7.0
#
#    GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0        11.0       15.0           14.0        8.0        €226.5M
# ...

# %% [markdown]
# # Histograma con matplotlib

# %%
plt.hist(dataframe['Overall'])
# Out:
# (array([  192.,   998.,  2363.,  4727.,  4289.,  3570.,  1513.,   445.,
#            96.,    14.]),
#  array([ 46. ,  50.8,  55.6,  60.4,  65.2,  70. ,  74.8,  79.6,  84.4,
#          89.2,  94. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Histograma con seaborn

# %%
sns.distplot(dataframe['Overall'])

# %%
sns.distplot(dataframe[dataframe.Nationality=='Argentina']['Overall'])
sns.distplot(dataframe[dataframe.Nationality=='Colombia']['Overall'])

# %% [markdown]
# # Iris Dataset y pairplots

# %%
iris = sns.load_dataset('iris')
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=3.0)

# %% [markdown]
# # Ejericio con dataset iris

# %%
import seaborn as sns

# %%
iris = pd.read_csv('./../../dataset/iris.csv')

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
sns.distplot(iris, hue='species', size=3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-93f4f701e25c> in <module>()
# ----> 1 sns.distplot(iris, hue='species', size=3.5)
#
# TypeError: distplot() got an unexpected keyword argument 'hue'
